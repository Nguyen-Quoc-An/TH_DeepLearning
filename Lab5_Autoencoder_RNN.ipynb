# %% [markdown]
# <a href="https://colab.research.google.com/github/Nguyen-Quoc-An/TH_DeepLearning/blob/main/Lab5_Autoencoder_RNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #AUTOENCODER

# %%
# Nạp thư viện
from keras.datasets import mnist
import numpy as np
import keras
from keras import layers

# %%
# Nạp dataset
(x_train, _), (x_test, _) = mnist.load_data()
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %%
# Xây dựng mô hình Autoencoder
encoding_dim = 32
input_img = keras.Input(shape=(784,))
encoded = layers.Dense(encoding_dim, activation='relu')(input_img)
decoded = layers.Dense(784, activation='sigmoid')(encoded)
autoencoder = keras.Model(input_img, decoded)
encoder = keras.Model(input_img, encoded)
encoded_input = keras.Input(shape=(encoding_dim,))
decoder_layer = autoencoder.layers[-1]
decoder = keras.Model(encoded_input, decoder_layer(encoded_input))

# %%
# Huấn luyện mô hình
autoencoder.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
autoencoder.fit(x_train, x_train,
                epochs=50,
                batch_size=256, verbose=1,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.0130 - loss: 0.0925 - val_accuracy: 0.0115 - val_loss: 0.0914
# Epoch 2/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0132 - loss: 0.0925 - val_accuracy: 0.0132 - val_loss: 0.0915
# Epoch 3/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0128 - loss: 0.0925 - val_accuracy: 0.0126 - val_loss: 0.0914
# Epoch 4/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.0128 - loss: 0.0925 - val_accuracy: 0.0126 - val_loss: 0.0914
# Epoch 5/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.0132 - loss: 0.0925 - val_accuracy: 0.0138 - val_loss: 0.0914
# Epoch 6/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0127 - loss: 0.0925 - val_accuracy: 0.0129 - val_loss: 0.0914
# Epoch 7/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0130 - loss: 0.0925 - val_accuracy: 0.0127 - val_loss: 0.0915
# Epoch 8/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.0127 - loss: 0.0925 - val_accuracy: 0.0135 - val_loss: 0.0914
# Epoch 9/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.0131 - loss: 0.0925 - val_accuracy: 0.0141 - val_loss: 0.0914
# Epoch 10/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.0128 - loss: 0.0925 - val_accuracy: 0.0141 - val_loss: 0.0914
# Epoch 11/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.0130 - loss: 0.0925 - val_accuracy: 0.0125 - val_loss: 0.0914
# Epoch 12/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.0128 - loss: 0.0925 - val_accuracy: 0.0126 - val_loss: 0.0913
# Epoch 13/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0132 - loss: 0.0925 - val_accuracy: 0.0148 - val_loss: 0.0914
# Epoch 14/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0130 - loss: 0.0924 - val_accuracy: 0.0125 - val_loss: 0.0914
# Epoch 15/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.0129 - loss: 0.0925 - val_accuracy: 0.0124 - val_loss: 0.0914
# Epoch 16/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0133 - loss: 0.0925 - val_accuracy: 0.0129 - val_loss: 0.0914
# Epoch 17/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.0134 - loss: 0.0924 - val_accuracy: 0.0124 - val_loss: 0.0914
# Epoch 18/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.0128 - loss: 0.0924 - val_accuracy: 0.0132 - val_loss: 0.0914
# Epoch 19/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0131 - loss: 0.0924 - val_accuracy: 0.0128 - val_loss: 0.0913
# Epoch 20/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0127 - loss: 0.0924 - val_accuracy: 0.0138 - val_loss: 0.0913
# Epoch 21/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0131 - loss: 0.0924 - val_accuracy: 0.0125 - val_loss: 0.0914
# Epoch 22/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.0128 - loss: 0.0924 - val_accuracy: 0.0141 - val_loss: 0.0914
# Epoch 23/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0126 - loss: 0.0924 - val_accuracy: 0.0129 - val_loss: 0.0914
# Epoch 24/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0127 - loss: 0.0924 - val_accuracy: 0.0131 - val_loss: 0.0914
# Epoch 25/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.0127 - loss: 0.0924 - val_accuracy: 0.0128 - val_loss: 0.0913
# Epoch 26/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.0130 - loss: 0.0924 - val_accuracy: 0.0139 - val_loss: 0.0915
# Epoch 27/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0130 - loss: 0.0924 - val_accuracy: 0.0121 - val_loss: 0.0913
# Epoch 28/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0129 - loss: 0.0924 - val_accuracy: 0.0140 - val_loss: 0.0914
# Epoch 29/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.0131 - loss: 0.0924 - val_accuracy: 0.0132 - val_loss: 0.0913
# Epoch 30/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.0131 - loss: 0.0924 - val_accuracy: 0.0125 - val_loss: 0.0913
# Epoch 31/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.0130 - loss: 0.0924 - val_accuracy: 0.0136 - val_loss: 0.0914
# Epoch 32/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0127 - loss: 0.0924 - val_accuracy: 0.0141 - val_loss: 0.0913
# Epoch 33/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - accuracy: 0.0124 - loss: 0.0924 - val_accuracy: 0.0132 - val_loss: 0.0914
# Epoch 34/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.0129 - loss: 0.0924 - val_accuracy: 0.0144 - val_loss: 0.0914
# Epoch 35/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.0127 - loss: 0.0924 - val_accuracy: 0.0145 - val_loss: 0.0915
# Epoch 36/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.0128 - loss: 0.0924 - val_accuracy: 0.0131 - val_loss: 0.0913
# Epoch 37/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0134 - loss: 0.0924 - val_accuracy: 0.0124 - val_loss: 0.0913
# Epoch 38/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.0130 - loss: 0.0924 - val_accuracy: 0.0140 - val_loss: 0.0913
# Epoch 39/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0129 - loss: 0.0924 - val_accuracy: 0.0132 - val_loss: 0.0913
# Epoch 40/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.0131 - loss: 0.0924 - val_accuracy: 0.0122 - val_loss: 0.0913
# Epoch 41/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.0128 - loss: 0.0924 - val_accuracy: 0.0129 - val_loss: 0.0913
# Epoch 42/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0127 - loss: 0.0923 - val_accuracy: 0.0144 - val_loss: 0.0913
# Epoch 43/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.0128 - loss: 0.0923 - val_accuracy: 0.0138 - val_loss: 0.0913
# Epoch 44/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - accuracy: 0.0130 - loss: 0.0923 - val_accuracy: 0.0126 - val_loss: 0.0915
# Epoch 45/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.0131 - loss: 0.0924 - val_accuracy: 0.0137 - val_loss: 0.0913
# Epoch 46/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.0131 - loss: 0.0923 - val_accuracy: 0.0147 - val_loss: 0.0913
# Epoch 47/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.0133 - loss: 0.0923 - val_accuracy: 0.0138 - val_loss: 0.0913
# Epoch 48/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.0130 - loss: 0.0923 - val_accuracy: 0.0132 - val_loss: 0.0913
# Epoch 49/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - accuracy: 0.0126 - loss: 0.0923 - val_accuracy: 0.0134 - val_loss: 0.0913
# Epoch 50/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.0131 - loss: 0.0923 - val_accuracy: 0.0137 - val_loss: 0.0913

# %%
# Dự báo loại ảnh sử dụng Autoencoder
encoded_imgs = encoder.predict(x_test)
decoded_imgs = decoder.predict(encoded_imgs)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
# Hiển thị ảnh từ mô hình Autoencoder
import matplotlib.pyplot as plt
n = 10
plt.figure(figsize=(20, 4))
for i in range(n):
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
#Thêm L1
import keras
from keras import layers
from keras import regularizers # Khai báo thêm thư viện này

encoding_dim = 32
input_img = keras.Input(shape=(784,))

# "encoded" is the encoded representation of the input
encoded = layers.Dense(encoding_dim, activity_regularizer=regularizers.l1(10e-5), activation='relu')(input_img)

# "decoded" is the lossy reconstruction of the input
decoded = layers.Dense(784, activation='sigmoid')(encoded)

autoencoder = keras.Model(input_img, decoded)
encoder = keras.Model(input_img, encoded)

encoded_input = keras.Input(shape=(encoding_dim,))
decoder_layer = autoencoder.layers[-1]
decoder = keras.Model(encoded_input, decoder_layer(encoded_input))

# %%
autoencoder.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
autoencoder.fit(x_train, x_train,
                epochs=100,
                batch_size=256, verbose=1,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.0141 - loss: 0.6551 - val_accuracy: 0.0143 - val_loss: 0.6155
# Epoch 2/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0149 - loss: 0.5833 - val_accuracy: 0.0161 - val_loss: 0.5535
# Epoch 3/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.0150 - loss: 0.5275 - val_accuracy: 0.0161 - val_loss: 0.5038
# Epoch 4/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.4827 - val_accuracy: 0.0161 - val_loss: 0.4638
# Epoch 5/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.0150 - loss: 0.4466 - val_accuracy: 0.0161 - val_loss: 0.4314
# Epoch 6/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.0150 - loss: 0.4174 - val_accuracy: 0.0161 - val_loss: 0.4050
# Epoch 7/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.3935 - val_accuracy: 0.0161 - val_loss: 0.3834
# Epoch 8/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.0150 - loss: 0.3739 - val_accuracy: 0.0161 - val_loss: 0.3656
# Epoch 9/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.0150 - loss: 0.3577 - val_accuracy: 0.0161 - val_loss: 0.3508
# Epoch 10/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.0150 - loss: 0.3442 - val_accuracy: 0.0161 - val_loss: 0.3385
# Epoch 11/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0147 - loss: 0.3329 - val_accuracy: 0.0161 - val_loss: 0.3281
# Epoch 12/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.3234 - val_accuracy: 0.0161 - val_loss: 0.3194
# Epoch 13/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.0150 - loss: 0.3154 - val_accuracy: 0.0161 - val_loss: 0.3120
# Epoch 14/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.0150 - loss: 0.3086 - val_accuracy: 0.0161 - val_loss: 0.3056
# Epoch 15/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.3027 - val_accuracy: 0.0161 - val_loss: 0.3002
# Epoch 16/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.0144 - loss: 0.2977 - val_accuracy: 0.0161 - val_loss: 0.2955
# Epoch 17/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.0150 - loss: 0.2934 - val_accuracy: 0.0161 - val_loss: 0.2915
# Epoch 18/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.2897 - val_accuracy: 0.0161 - val_loss: 0.2880
# Epoch 19/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0148 - loss: 0.2865 - val_accuracy: 0.0161 - val_loss: 0.2850
# Epoch 20/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.2836 - val_accuracy: 0.0161 - val_loss: 0.2823
# Epoch 21/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.0154 - loss: 0.2812 - val_accuracy: 0.0161 - val_loss: 0.2800
# Epoch 22/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.2790 - val_accuracy: 0.0161 - val_loss: 0.2780
# Epoch 23/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.2772 - val_accuracy: 0.0161 - val_loss: 0.2762
# Epoch 24/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.2755 - val_accuracy: 0.0161 - val_loss: 0.2746
# Epoch 25/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.0149 - loss: 0.2741 - val_accuracy: 0.0161 - val_loss: 0.2733
# Epoch 26/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.2728 - val_accuracy: 0.0161 - val_loss: 0.2721
# Epoch 27/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0149 - loss: 0.2717 - val_accuracy: 0.0161 - val_loss: 0.2710
# Epoch 28/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.0150 - loss: 0.2707 - val_accuracy: 0.0161 - val_loss: 0.2700
# Epoch 29/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.0150 - loss: 0.2698 - val_accuracy: 0.0161 - val_loss: 0.2692
# Epoch 30/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.0150 - loss: 0.2690 - val_accuracy: 0.0161 - val_loss: 0.2685
# Epoch 31/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.2683 - val_accuracy: 0.0161 - val_loss: 0.2678
# Epoch 32/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.0150 - loss: 0.2677 - val_accuracy: 0.0161 - val_loss: 0.2672
# Epoch 33/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.2672 - val_accuracy: 0.0161 - val_loss: 0.2667
# Epoch 34/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.0150 - loss: 0.2667 - val_accuracy: 0.0161 - val_loss: 0.2663
# Epoch 35/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.2663 - val_accuracy: 0.0161 - val_loss: 0.2658
# Epoch 36/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.0150 - loss: 0.2659 - val_accuracy: 0.0161 - val_loss: 0.2655
# Epoch 37/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.2656 - val_accuracy: 0.0161 - val_loss: 0.2652
# Epoch 38/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.2653 - val_accuracy: 0.0161 - val_loss: 0.2649
# Epoch 39/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.0150 - loss: 0.2650 - val_accuracy: 0.0161 - val_loss: 0.2646
# Epoch 40/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.0149 - loss: 0.2648 - val_accuracy: 0.0161 - val_loss: 0.2644
# Epoch 41/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.2645 - val_accuracy: 0.0161 - val_loss: 0.2642
# Epoch 42/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.2644 - val_accuracy: 0.0161 - val_loss: 0.2640
# Epoch 43/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.0150 - loss: 0.2642 - val_accuracy: 0.0161 - val_loss: 0.2638
# Epoch 44/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.0150 - loss: 0.2640 - val_accuracy: 0.0161 - val_loss: 0.2637
# Epoch 45/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.2639 - val_accuracy: 0.0161 - val_loss: 0.2636
# Epoch 46/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.2638 - val_accuracy: 0.0161 - val_loss: 0.2635
# Epoch 47/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.0149 - loss: 0.2637 - val_accuracy: 0.0161 - val_loss: 0.2633
# Epoch 48/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.0150 - loss: 0.2636 - val_accuracy: 0.0161 - val_loss: 0.2633
# Epoch 49/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.0150 - loss: 0.2635 - val_accuracy: 0.0161 - val_loss: 0.2632
# Epoch 50/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.0150 - loss: 0.2634 - val_accuracy: 0.0161 - val_loss: 0.2631
# Epoch 51/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.0150 - loss: 0.2634 - val_accuracy: 0.0161 - val_loss: 0.2630
# Epoch 52/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.2633 - val_accuracy: 0.0161 - val_loss: 0.2630
# Epoch 53/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.2632 - val_accuracy: 0.0161 - val_loss: 0.2629
# Epoch 54/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.0150 - loss: 0.2632 - val_accuracy: 0.0161 - val_loss: 0.2629
# Epoch 55/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.2631 - val_accuracy: 0.0161 - val_loss: 0.2628
# Epoch 56/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.0150 - loss: 0.2631 - val_accuracy: 0.0161 - val_loss: 0.2628
# Epoch 57/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.0150 - loss: 0.2631 - val_accuracy: 0.0161 - val_loss: 0.2628
# Epoch 58/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.0150 - loss: 0.2630 - val_accuracy: 0.0161 - val_loss: 0.2628
# Epoch 59/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.2630 - val_accuracy: 0.0161 - val_loss: 0.2627
# Epoch 60/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.2630 - val_accuracy: 0.0161 - val_loss: 0.2627
# Epoch 61/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.0150 - loss: 0.2630 - val_accuracy: 0.0161 - val_loss: 0.2627
# Epoch 62/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.0150 - loss: 0.2630 - val_accuracy: 0.0161 - val_loss: 0.2627
# Epoch 63/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0148 - loss: 0.2629 - val_accuracy: 0.0161 - val_loss: 0.2626
# Epoch 64/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.0150 - loss: 0.2629 - val_accuracy: 0.0161 - val_loss: 0.2626
# Epoch 65/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.0150 - loss: 0.2629 - val_accuracy: 0.0161 - val_loss: 0.2626
# Epoch 66/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.2629 - val_accuracy: 0.0161 - val_loss: 0.2626
# Epoch 67/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.0150 - loss: 0.2629 - val_accuracy: 0.0161 - val_loss: 0.2626
# Epoch 68/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.0148 - loss: 0.2629 - val_accuracy: 0.0161 - val_loss: 0.2626
# Epoch 69/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0149 - loss: 0.2629 - val_accuracy: 0.0161 - val_loss: 0.2626
# Epoch 70/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.2629 - val_accuracy: 0.0161 - val_loss: 0.2626
# Epoch 71/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.2629 - val_accuracy: 0.0161 - val_loss: 0.2626
# Epoch 72/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.0150 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2626
# Epoch 73/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2626
# Epoch 74/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2626
# Epoch 75/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.0146 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2626
# Epoch 76/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.0150 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2625
# Epoch 77/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0149 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2625
# Epoch 78/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0153 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2625
# Epoch 79/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.0150 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2625
# Epoch 80/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.0150 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2625
# Epoch 81/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.0150 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2625
# Epoch 82/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2625
# Epoch 83/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.0143 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2625
# Epoch 84/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.0150 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2625
# Epoch 85/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.0150 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2625
# Epoch 86/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.0150 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2625
# Epoch 87/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.0150 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2625
# Epoch 88/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.0150 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2625
# Epoch 89/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.0150 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2625
# Epoch 90/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2625
# Epoch 91/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.0150 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2625
# Epoch 92/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.0150 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2625
# Epoch 93/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.0150 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2625
# Epoch 94/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.0150 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2625
# Epoch 95/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.0150 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2625
# Epoch 96/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.0143 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2625
# Epoch 97/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0150 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2625
# Epoch 98/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.0149 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2625
# Epoch 99/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.0150 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2625
# Epoch 100/100
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.0150 - loss: 0.2628 - val_accuracy: 0.0161 - val_loss: 0.2625

# %%
encoding_dim = 32
input_img = keras.Input(shape=(784,))
encoded = layers.Dense(128, activation='relu')(input_img)
encoded = layers.Dense(64, activation='relu')(encoded)
encoded = layers.Dense(encoding_dim, activation='relu')(encoded)
decoded = layers.Dense(784, activation='sigmoid')(encoded)
autoencoder = keras.Model(input_img, decoded)
encoder = keras.Model(input_img, encoded)
encoded_input = keras.Input(shape=(32,))
decoder_layer = autoencoder.layers[-1]
decoder = keras.Model(encoded_input, decoder_layer(encoded_input))

# %%
import keras
from keras import layers
from keras.datasets import cifar10
import numpy as np
import matplotlib.pyplot as plt

# 1. Tải và Tiền xử lý dữ liệu CIFAR-10
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Chuẩn hóa dữ liệu về khoảng [0, 1] kiểu float32
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.

# Lưu ý: Chúng ta KHÔNG reshape (flatten) dữ liệu như MNIST
# Kích thước giữ nguyên là (số_lượng_ảnh, 32, 32, 3)
print(f"Hình dạng x_train: {x_train.shape}")
print(f"Hình dạng x_test: {x_test.shape}")

# 2. Xây dựng mô hình Convolutional Autoencoder
input_img = keras.Input(shape=(32, 32, 3))

# --- Phần MÃ HÓA (Encoder) ---
# Dùng Conv2D để trích xuất đặc trưng và MaxPooling2D để nén kích thước
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(input_img)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(x)
encoded = layers.MaxPooling2D((2, 2), padding='same')(x)
# Kích thước không gian lúc này đã bị nén lại thành (8, 8, 16)

# --- Phần GIẢI MÃ (Decoder) ---
# Dùng UpSampling2D để khôi phục lại kích thước ban đầu
x = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(encoded)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = layers.UpSampling2D((2, 2))(x)

# Lớp đầu ra dùng 3 filter tương ứng với 3 kênh màu (R, G, B)
decoded = layers.Conv2D(3, (3, 3), activation='sigmoid', padding='same')(x)

# Gom lại thành mô hình hoàn chỉnh
autoencoder = keras.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# In ra tóm tắt kiến trúc mạng
autoencoder.summary()

# 3. Huấn luyện mô hình
# (Bạn có thể tăng số epochs lên 50 hoặc 100 nếu muốn ảnh nét hơn)
autoencoder.fit(x_train, x_train,
                epochs=20,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))

# 4. Dự đoán và Hiển thị Kết quả
decoded_imgs = autoencoder.predict(x_test)

# Định nghĩa dictionary nhãn từ bảng mô tả
cifar10_labels = {
    0: 'airplane', 1: 'automobile', 2: 'bird', 3: 'cat', 4: 'deer',
    5: 'dog', 6: 'frog', 7: 'horse', 8: 'ship', 9: 'truck'
}

n = 10  # Số lượng ảnh hiển thị
plt.figure(figsize=(20, 5))
for i in range(n):
    # --- Hiển thị ảnh gốc ---
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i])
    # Lấy nhãn tương ứng để làm tiêu đề
    label_index = y_test[i][0]
    plt.title(cifar10_labels[label_index])
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # --- Hiển thị ảnh tái tạo ---
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i])
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

plt.tight_layout()
plt.show()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 12s 0us/step
# Hình dạng x_train: (50000, 32, 32, 3)
# Hình dạng x_test: (10000, 32, 32, 3)
# Model: "functional_18"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_14 (InputLayer)     │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 16, 16, 16)     │         4,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 8, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 8, 8, 16)       │         2,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d (UpSampling2D)    │ (None, 16, 16, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_1 (UpSampling2D)  │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 32, 32, 3)      │           867 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13,347 (52.14 KB)
#  Trainable params: 13,347 (52.14 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 158s 793ms/step - loss: 0.5962 - val_loss: 0.5753
# Epoch 2/20
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 198s 771ms/step - loss: 0.5710 - val_loss: 0.5691
# Epoch 3/20
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 149s 758ms/step - loss: 0.5671 - val_loss: 0.5669
# Epoch 4/20
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 153s 782ms/step - loss: 0.5653 - val_loss: 0.5653
# Epoch 5/20
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 196s 750ms/step - loss: 0.5642 - val_loss: 0.5645
# Epoch 6/20
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 147s 748ms/step - loss: 0.5634 - val_loss: 0.5637
# Epoch 7/20
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 147s 750ms/step - loss: 0.5627 - val_loss: 0.5632
# Epoch 8/20
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 147s 750ms/step - loss: 0.5622 - val_loss: 0.5627
# Epoch 9/20
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 201s 748ms/step - loss: 0.5618 - val_loss: 0.5624
# Epoch 10/20
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 204s 756ms/step - loss: 0.5613 - val_loss: 0.5619
# Epoch 11/20
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 203s 759ms/step - loss: 0.5610 - val_loss: 0.5623
# Epoch 12/20
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 199s 745ms/step - loss: 0.5607 - val_loss: 0.5616
# Epoch 13/20
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 204s 754ms/step - loss: 0.5604 - val_loss: 0.5609
# Epoch 14/20
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 146s 745ms/step - loss: 0.5601 - val_loss: 0.5608
# Epoch 15/20
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 206s 764ms/step - loss: 0.5600 - val_loss: 0.5605
# Epoch 16/20
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 150s 763ms/step - loss: 0.5597 - val_loss: 0.5604
# Epoch 17/20
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 201s 759ms/step - loss: 0.5595 - val_loss: 0.5601
# Epoch 18/20
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 149s 761ms/step - loss: 0.5593 - val_loss: 0.5602
# Epoch 19/20
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 146s 746ms/step - loss: 0.5591 - val_loss: 0.5604
# Epoch 20/20
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 147s 748ms/step - loss: 0.5589 - val_loss: 0.5596
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step

# %% [markdown]
# #RNN

# %%
from pandas import read_csv
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Input
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import math
import matplotlib.pyplot as plt

# %%
# 2. Định nghĩa hàm và tạo mô hình
#hidden_units: 2 blocks
#dense_units : 1 block
#input_shape: (time steps x features)
#activation: linear f(x) = x

def create_RNN(hidden_units, dense_units, input_shape, activation):
    model = Sequential()

    # Sử dụng Input layer để khai báo kích thước đầu vào
    model.add(Input(shape=input_shape))

    # Lớp SimpleRNN không cần khai báo input_shape nữa
    model.add(SimpleRNN(hidden_units, activation=activation[0]))

    model.add(Dense(dense_units, activation=activation[1]))

    model.compile(optimizer='adam', loss='mean_squared_error')

    return model

# 3. Khởi tạo mô hình
demo_RNN = create_RNN(2, 1, (3, 1), ['linear', 'linear'])

# (Tùy chọn) In tóm tắt mô hình ra để kiểm tra
demo_RNN.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn_1 (SimpleRNN)        │ (None, 2)              │             8 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             3 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 11 (44.00 B)
#  Trainable params: 11 (44.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
wx = demo_RNN.get_weights()[0]
wh = demo_RNN.get_weights()[1]
bh = demo_RNN.get_weights()[2]
wy = demo_RNN.get_weights()[3]
by = demo_RNN.get_weights()[4]

print('wx=', wx)
print('wh=', wh)
print('bh=', bh)
print('wy=', wy)
print('by=', by)
# Out:
# wx= [[ 1.284119  -0.0819813]]
# wh= [[-0.66537035  0.74651325]
#  [ 0.74651325  0.6653705 ]]
# bh= [0. 0.]
# wy= [[0.8415276]
#  [1.1558102]]
# by= [0.]

# %%
x = np.array([1, 2, 3])
# Reshape the input to the required sample_size x time_steps x features
x_input = np.reshape(x, (1, 3, 1))
y_predict_model = demo_RNN.predict(x_input)

m = 2
h0 = np.zeros(m)
h1 = np.dot(x[0], wx) + bh + h0
h2 = np.dot(x[1], wx) + np.dot(h1, wh) + bh
h3 = np.dot(x[2], wx) + np.dot(h2, wh) + bh

o3 = np.dot(h3, wy) + by

print('h1:', h1)
print('h2:', h2)
print('h3:', h3)

print('Prediction of model:', y_predict_model)
print('Prediction from computation:', o3)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
# h1: [[ 1.28411901 -0.0819813 ]]
# h2: [[1.65262318 0.74010131]]
# h3: [[3.305246   1.48020279]]
# Prediction of model: [[4.492289]]
# Prediction from computation: [[4.49228921]]

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

def get_train_test(url, split_percent=0.8):
    # Khai báo biến pd.read_csv hoạt động bình thường
    df = pd.read_csv(url, usecols=[1], engine='python')
    data = np.array(df.values.astype('float32'))
    scaler = MinMaxScaler(feature_range=(0, 1))
    data = scaler.fit_transform(data).flatten()

    n = len(data)

    split = int(n * split_percent)
    train_data = data[range(split)]
    test_data = data[split:]
    return train_data, test_data, data

sunspots_url = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/monthly-sunspots.csv'
train_data, test_data, data = get_train_test(sunspots_url)

# %%
def get_XY(dat, time_steps):
    #indices target arrays
    y_ind = np.arange(time_steps, len(dat), time_steps)
    Y = dat[y_ind]

    #prepare X
    row_x = len(Y)
    X = dat[range(time_steps * row_x)]
    X = np.reshape(X, (row_x, time_steps, 1))
    return X, Y

time_steps = 12
trainX, trainY = get_XY(train_data, time_steps)
testX, testY = get_XY(test_data, time_steps)

# %%
model = create_RNN(hidden_units=3, dense_units=1, input_shape=(time_steps,1), activation=['tanh', 'tanh'])
model_fit = model.fit(trainX, trainY, epochs=20, verbose=1)
# Out:
# Epoch 1/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.1120
# Epoch 2/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0865
# Epoch 3/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0659
# Epoch 4/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0497
# Epoch 5/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0384
# Epoch 6/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0304
# Epoch 7/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0251
# Epoch 8/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0219
# Epoch 9/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0197
# Epoch 10/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0180
# Epoch 11/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0169
# Epoch 12/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0159
# Epoch 13/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0151
# Epoch 14/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0145
# Epoch 15/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0138
# Epoch 16/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0132
# Epoch 17/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0126
# Epoch 18/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0121
# Epoch 19/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0116
# Epoch 20/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0110

# %%
def print_error(trainY, testY, train_predict, test_predict):
    # Error of predictions
    train_rmse = math.sqrt(mean_squared_error(trainY, train_predict))
    test_rmse = math.sqrt(mean_squared_error(testY, test_predict))
    # Print RMSE
    print('Train RMSE: %.3f RMSE' % (train_rmse))
    print('Test RMSE: %.3f RMSE' % (test_rmse))

# make predictions
train_predict = model.predict(trainX)
test_predict = model.predict(testX)
# Mean square error
print_error(trainY, testY, train_predict, test_predict)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 147ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Train RMSE: 0.104 RMSE
# Test RMSE: 0.167 RMSE

# %%
# Plot the result
def plot_result(trainY, testY, train_predict, test_predict):
    actual = np.append(trainY, testY)
    predictions = np.append(train_predict, test_predict)
    rows = len(actual)
    plt.figure(figsize=(15, 6), dpi=80)
    plt.plot(range(rows), actual)
    plt.plot(range(rows), predictions)
    plt.axvline(x=len(trainY), color='r')
    plt.legend(['Actual', 'Predictions'])
    plt.xlabel('Observation number after given time steps')
    plt.ylabel('Sunspots scaled')
    plt.title('Actual and Predicted Values. The Red Line Separates The Training And Test Examples')
    plt.show()

plot_result(trainY, testY, train_predict, test_predict)
